# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# cricket: --> name, age, runs, average, captain

# %% [markdown]
# # VARIABLES

# %% [markdown]
# KING="VIRAT KOHLI"
#
# GOD="SACHIN"
#
# ROCKING_STAR = "YASH"

# %% [markdown]
# variable_name = value

# %%
KING="VIRAT KOHLI"

# %%
print(KING)
# Out:
# VIRAT KOHLI

# %%
print("hello")
# Out:
# hello

# %%
player_name = "VIRAT KOHLI"
age = 35
batting_average = 50.5
is_captain = False
jersey_numbers = 18

# %%
type(player_name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(is_captain)
# Out:
# bool

# %%
type(batting_average)
# Out:
# float

# %%
# printing the values of the variables
print("================================")
print("Player Name:", player_name)
print("Age:", age)
print("Batting Average:", batting_average)
print("Is Captain:", is_captain)
print("Jersey Numbers:", jersey_numbers)
print("================================")
# Out:
# ...
# Player Name: VIRAT KOHLI
# Age: 35
# Batting Average: 50.5
# Is Captain: False
# Jersey Numbers: 18
# ...

# %%
# basic data types in python
# 1. String: A string is a sequence of characters enclosed in single quotes (' ') or 
# double quotes (" "). It is used to represent text data. For example:

print("This is a string.")
# Out:
# This is a string.

# %%
test = "This is a string."

# %%
test = 'This is a string.'

# %%
print(hello manoj)
# Out:
#   Cell In[14], line 1
#     print(hello manoj)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
test = hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 test = hello
#
# NameError: name 'hello' is not defined

# %%
player_name = "VIRAT KOHLI"
team_name = "INDIA"
nickname = "KING KOHLI"
homeground = "banglore"
IPL_team = 'RCB'

# %%
print(nickname)
# Out:
# KING KOHLI

# %%
type(player_name)
# Out:
# str

# %%
IPL_team = 'RCB'
type(IPL_team )
# Out:
# str

# %%
test = "10"

# %%
type(test)
# Out:
# str

# %%
test = 10

# %%
#2 integers

matches_played = 100
centruries = 80
sixes_hit = 200
jessey_number = 18

# %%
type(age)
# Out:
# int

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
batting_average = 50.5
strike_rate = 130.5
economy_rate = 7.5

# %%
print(batting_average)
# Out:
# 50.5

# %%
type(batting_average)
# Out:
# float

# %%
# boolean 
is_captain = True
is_injured = False
is_overseas_player = True

# %%
type(is_captain)
# Out:
# bool

# %%
retirement_date = None

# %%
name = "null"

# %%
print(name)
# Out:
# null

# %%
name=
# Out:
#   Cell In[37], line 1
#     name=
#          ^
# SyntaxError: invalid syntax

# %%
print(name)

# %% [markdown]
# # variables rules

# %%
player_name = "VIRAT KOHLI"
totol_runs = 12000
matches_played = 100

# %%
1player_name = "VIRAT KOHLI"
# Out:
#   Cell In[39], line 1
#     1player_name = "VIRAT KOHLI"
#     ^
# SyntaxError: invalid decimal literal

# %%
player name = "VIRAT KOHLI"
# Out:
#   Cell In[40], line 1
#     player name = "VIRAT KOHLI"
#            ^
# SyntaxError: invalid syntax

# %%
player-name = "VIRAT KOHLI"
# Out:
#   Cell In[41], line 1
#     player-name = "VIRAT KOHLI"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a=10
a="Msdhoni"
data =103636
n=1e35
