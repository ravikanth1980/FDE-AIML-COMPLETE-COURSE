# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# cricket: --> name, age, runs, average, captain

# %% [markdown]
# # VARIABLES

# %% [markdown]
# KING="VIRAT KOHLI"
#
# GOD="SACHIN"
#
# ROCKING_STAR = "YASH"

# %% [markdown]
# variable_name = value

# %%
KING="VIRAT KOHLI"

# %%
print(KING)
# Out:
# VIRAT KOHLI

# %%
print("hello")
# Out:
# hello

# %%
player_name = "VIRAT KOHLI"
age = 35
batting_average = 50.5
is_captain = False
jersey_numbers = 18

# %%
type(player_name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(is_captain)
# Out:
# bool

# %%
type(batting_average)
# Out:
# float

# %%
# printing the values of the variables
print("================================")
print("Player Name:", player_name)
print("Age:", age)
print("Batting Average:", batting_average)
print("Is Captain:", is_captain)
print("Jersey Numbers:", jersey_numbers)
print("================================")
# Out:
# ...
# Player Name: VIRAT KOHLI
# Age: 35
# Batting Average: 50.5
# Is Captain: False
# Jersey Numbers: 18
# ...

# %%
# basic data types in python
# 1. String: A string is a sequence of characters enclosed in single quotes (' ') or 
# double quotes (" "). It is used to represent text data. For example:

print("This is a string.")
# Out:
# This is a string.

# %%
test = "This is a string."

# %%
test = 'This is a string.'

# %%
print(hello manoj)
# Out:
#   Cell In[14], line 1
#     print(hello manoj)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
test = hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 test = hello
#
# NameError: name 'hello' is not defined

# %%
player_name = "VIRAT KOHLI"
team_name = "INDIA"
nickname = "KING KOHLI"
homeground = "banglore"
IPL_team = 'RCB'

# %%
print(nickname)
# Out:
# KING KOHLI

# %%
type(player_name)
# Out:
# str

# %%
IPL_team = 'RCB'
type(IPL_team )
# Out:
# str

# %%
test = "10"

# %%
type(test)
# Out:
# str

# %%
test = 10

# %%
#2 integers

matches_played = 100
centruries = 80
sixes_hit = 200
jessey_number = 18

# %%
type(age)
# Out:
# int

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
batting_average = 50.5
strike_rate = 130.5
economy_rate = 7.5

# %%
print(batting_average)
# Out:
# 50.5

# %%
type(batting_average)
# Out:
# float

# %%
# boolean 
is_captain = True
is_injured = False
is_overseas_player = True

# %%
type(is_captain)
# Out:
# bool

# %%
retirement_date = None

# %%
name = "null"

# %%
print(name)
# Out:
# null

# %%
name=
# Out:
#   Cell In[37], line 1
#     name=
#          ^
# SyntaxError: invalid syntax

# %%
print(name)

# %% [markdown]
# # variables rules

# %%
player_name = "VIRAT KOHLI"
totol_runs = 12000
matches_played = 100

# %%
1player_name = "VIRAT KOHLI"
# Out:
#   Cell In[39], line 1
#     1player_name = "VIRAT KOHLI"
#     ^
# SyntaxError: invalid decimal literal

# %%
player name = "VIRAT KOHLI"
# Out:
#   Cell In[40], line 1
#     player name = "VIRAT KOHLI"
#            ^
# SyntaxError: invalid syntax

# %%
player-name = "VIRAT KOHLI"
# Out:
#   Cell In[41], line 1
#     player-name = "VIRAT KOHLI"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a=10
a="Msdhoni"
data =103636
n=1e35

# %% [markdown]
# # operators

# %% [markdown]
# # arthimetic operators
# - addition
# - substractions
# - multiplication
# - division
# - floor division
# - modulus
# - exponentials
#
# # comperasion operators
# - equal to
# - not equal to
# - greater then
# - less than
# - greater than or equal to
# - less than or equal to
#
# # Logical operators
# - AND
# - OR
# - NOT

# %%
# arthimetic operators
A = 10
B = 5

# %%
add = A + B
sub = A - B
mul = A * B
div = A / B
mod = A % B 
floor_div = A // B
exponent = A ** B

# %%
print("Addition:", add)
print("Subtraction:", sub)
print("Multiplication:", mul)
print("Division:", div)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0

# %%
print("floor_div:", floor_div)
# Out:
# floor_div: 2

# %%
print("exponent:", exponent)
# Out:
# exponent: 100000

# %%
# comparison operators

a = 10
b = 10

a == b
# Out:
# True

# %%
a = "manoj"
b = "manoj"

# %%
a == b
# Out:
# True

# %%
a != b
# Out:
# False

# %%
x = 10
y = 20

x > y
# Out:
# False

# %%
y > x
# Out:
# True

# %%
a =! b

# %%
a >= b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a >= b
#
# TypeError: '>=' not supported between instances of 'SList' and 'str'

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

# arithmetic operations

addition = num1 + num2
subtraction = num1 - num2   
multiplication = num1 * num2
division = num1 / num2
floor_division = num1 // num2
modulus = num1 % num2
exponentiation = num1 ** num2


# display results
print("="*45)
print("Results:")
print(f"Addition: {addition}")
print(f"Subtraction: {subtraction}")
print(f"Multiplication: {multiplication}")
print(f"Division: {division}")
print(f"Floor Division: {floor_division}")
print(f"Modulus: {modulus}")
print(f"Exponentiation: {exponentiation}")
print("="*45)
# Out:
# ...
# Results:
# Addition: 30
# Subtraction: -10
# Multiplication: 200
# Division: 0.5
# Floor Division: 0
# Modulus: 10
# Exponentiation: 100000000000000000000
# ...

# %%
# input() always return a string

a = input("enter your name: ")

# %%
print(a)
# Out:
# Manoj

# %%
type(a)
# Out:
# str

# %%
a = input("enter your name: ")

# %%
print(a)
# Out:
# 20

# %%
type(a)
# Out:
# str

# %%
a = input("enter your name: ")
b = input("enter your phone number: ")
c = input("enter your email: ")

# %%
print(a)
# Out:
# Manoj

# %%
print(b)
# Out:
# 12573286236

# %%
print(c)
# Out:
# manoj@gmail.com

# %%
type(b)
# Out:
# str

# %%
a + b
# Out:
# 'Manoj12573286236'

# %%
a*b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 a*b
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
user_input_age = "28" # --> this is string

actual_age = int(user_input_age) # it converts the string to an integer

# %%
print(user_input_age)
# Out:
# 28

# %%
print(actual_age)
# Out:
# 28

# %%
type(actual_age)
# Out:
# int

# %%
print(type(user_input_age))
# Out:
# <class 'str'>

# %%
user_input_age = input("Enter your age: ")

actual_age = int(user_input_age)

print(type(actual_age))
years_until_retirement = 60 - actual_age

print("You have", years_until_retirement, "years until retirement.")
# Out:
# <class 'int'>
# You have 25 years until retirement.

# %%
score = int(input("Enter your score: "))

type(score)

print("Your score is:", score)
# Out:
# Your score is: 1000

# %%
type(score)
# Out:
# int

# %%
score = float(input("Enter your score: "))

# %%
print(score)
# Out:
# 10.0

# %%
type(score)
# Out:
# float

# %%
number = 42
text = "100"
decimal_number = 3.14

# %%
print(str(number)) ## 42 --> "42" (int to string conversion)
# Out:
# 42

# %%
a = str(number)

# %%
print(a)
# Out:
# 42

# %%
type(a)
# Out:
# str

# %%
print(int(text)) ## "100" --> 100 (string to int conversion)
# Out:
# 100

# %%
print(float(number)) ## converting int to float
# Out:
# 42.0

# %%
print(int(decimal_number)) ## converting float to int
# Out:
# 3

# %%
# BOOL 
print(bool(0))
# Out:
# False

# %%
bool("hello")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
print("🏏 CRICKET BATTING AVERAGE CALCULATOR")
print("="*45)

player_name = input("Enter player name: ")
total_runs = int(input("Enter total runs scored: "))
total_innings = int(input("Enter innings played: "))
not_out = int(input("Enter number of times not out: "))

# calculate
actual_innings = total_innings - not_out
batting_average = total_runs / actual_innings 

print()
print("player name:", player_name)
print("total runs:", total_runs)
print("actual innings:", actual_innings)
print("batting average:", round(batting_average, 2))
print("="*45)
print()

if batting_average >= 50:
    print("Excellent batting average!")
elif batting_average >= 40:
    print("Good batting average!")
elif batting_average >= 30:
    print("Average batting average!")
else:
    print("Below average batting average!")
# Out:
# 🏏 CRICKET BATTING AVERAGE CALCULATOR
# ...
#
# player name: virat
# total runs: 180000
# actual innings: 260
# batting average: 692.31
# ...
#
# Excellent batting average!

# %%
print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %%
print(1)
print()
print(2)
print()
print(3)
# Out:
# 1
#
# 2
#
# 3

# %% [markdown]
# # Build: Zomato Delivery Bill Calculator

# %% [markdown]
# ```
# Requirements:
# 1. Ask user: restaurant name, number of items, price per item
# 2. Calculate: subtotal, tax (18% GST), delivery charge (Rs 40), total
# 3. Ask user: did they order veg or non-veg? (affects any surcharge)
# 4. Print a formatted bill receipt with all details
#
# Expected output:
# ╔══════════════════════════════════╗
# ║        ZOMATO ORDER RECEIPT      ║
# ╠══════════════════════════════════╣
# ║ Restaurant : Pizza Hut           ║
# ║ Items      : 3 × Rs 350 each     ║
# ║ Subtotal   : Rs 1050             ║
# ║ GST (18%)  : Rs 189              ║
# ║ Delivery   : Rs 40               ║
# ║ TOTAL      : Rs 1279             ║
# ╚══════════════════════════════════╝
#
# ```

# %% [markdown]
# ```
