# %% [markdown]
# # STRINGS

# %%
# single line strings
name = "smriti mandana"
player = "RCB"

# %%
## multiline_string 

dailogue = """
Violence… 
Violence… 
Violence! 
I don’t like violence, 
but violence likes me.
"""

# %%
print(dailogue)`
# Out:
# Violence…
# Violence…
# Violence!
# I don’t like violence,
# but violence likes me.

# %%
dailogue = ""
Violence… 
Violence… 
Violence! 
I don’t like violence, 
but violence likes me.
""
# Out:
#   Cell In[5], line 2
#     Violence…
#             ^
# SyntaxError: invalid character '…' (U+2026)

# %%
dailogue = """
Violence… 
Violence… 
Violence! 
I don’t like violence, 
but violence likes me.
"""

# %%
dailogue = '''
Violence… 
Violence… 
Violence! 
I don’t like violence, 
but violence likes me.
'''

# %%
name = "smriti"

# %%
print("Lenghth of the string is: ", len(name))
# Out:
# Lenghth of the string is:  6

# %%
len(name)
# Out:
# 6

# %%
a = len(name)

# %%
print(a)
# Out:
# 6

# %%
name = "smriti :" mandana"
# Out:
#   Cell In[20], line 1
#     name = "smriti :" mandana"
#                              ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
len(name)
# Out:
# 16

# %%
name = "smriti mandana is very 'good' player "

# %%
print(name)
# Out:
# smriti mandana is very 'good' player

# %%
name = "smriti"

# %%
print("first character of the string is: ", name[0])
# Out:
# first character of the string is:  s

# %%
print("last character of the string is: ", name[-1])
# Out:
# last character of the string is:  i

# %%
username = "Smriti_Mandhana_18"

# %%
len(username)
# Out:
# 18

# %%
username = "Smriti_Mandhana_18"
print(f"username : {username}")
print(f"First 8 charcters : {username[:8]}")
print(f"First 8 charcters : {username[2:8]}")
print(f"Last Charcter is : {username[-1]}")
print(f"Len of the username is {len(username)} hi akaknsha {name}")
# Out:
# username : Smriti_Mandhana_18
# First 8 charcters : Smriti_M
# First 8 charcters : riti_M
# Last Charcter is : 8
# Len of the username is 18 hi akaknsha smriti

# %%
username = "Smriti_Mandhana_18"
username[0]
# Out:
# 'S'

# %%
username[8]
# Out:
# 'a'

# %%
username[:8]
# Out:
# 'Smriti_M'

# %%
print(f"")

# %%
# string slicing -- string[start:end:step]

WORD = "BOLLYWOOD"

# %%
WORD[0:5]
# Out:
# 'BOLLY'

# %%
WORD[::1]
# Out:
# 'BOLLYWOOD'

# %%
WORD[::2]
# Out:
# 'BLYOD'

# %%
WORD[::-1]
# Out:
# 'DOOWYLLOB'

# %%
PHONE = "+91-897938O899"
PHONE[0:-1]
type(PHONE)
# Out:
# str

# %%
county_code = PHONE[:3]
number_part = PHONE[4:]

# %%
print(f"phone : {PHONE}")
print(f"country code is : {county_code}")
print(f"Number: {number_part}")
# Out:
# phone : +91-897938O899
# country code is : +91
# Number: 897938O899

# %% [markdown]
# # [START:END:STEP]
#
# - [1]
# - [1:]
# - [::4]

# %%
a = 98946486

# %%
a[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 a[1]
#
# TypeError: 'int' object is not subscriptable

# %%
name = " Manoj krishnappa "

# %%
print(name)
# Out:
#  Manoj

# %%
len(name)
# Out:
# 7

# %%
print(name.strip())
# Out:
# Manoj

# %%
good_name = name.strip()

# %%
print(good_name)
# Out:
# Manoj

# %%
len(good_name)
# Out:
# 5

# %%
good_name.upper()
# Out:
# 'MANOJ'

# %%
good_name.lower()
# Out:
# 'manoj'

# %%
good_name.title()
# Out:
# 'Manoj'

# %%
restaurant = input("Enter restaurant name: ")
items = int(input("Enter number of items: "))
price = float(input("Enter price per item: "))
food_type = input("Did you order veg or non-veg? ").lower()

subtotal = items * price
gst = subtotal * 0.18
delivery = 40

# Example surcharge
surcharge = 0
if food_type == "non-veg":
    surcharge = 0

total = subtotal + gst + delivery + surcharge

print("╔ ═ ═ ═ ═ ═ ═ ════════════════════════════╗")

print("║        ZOMATO ORDER RECEIPT      ║")
print("╠══════════════════════════════════╣")
print(f"║ Restaurant : {restaurant:<20} ║")
print(f"║ Items      : {items} × Rs {price:<11.0f} ║")
print(f"║ Subtotal   : Rs {subtotal:<16.0f} ║")
print(f"║ GST (18%)  : Rs {gst:<16.0f} ║")
print(f"║ Delivery   : Rs {delivery:<16.0f} ║")
print(f"║ TOTAL      : Rs {total:<16.0f} ║")
print("╚══════════════════════════════════╝")
# Out:
# ╔══════════════════════════════════╗
# ║        ZOMATO ORDER RECEIPT      ║
# ╠══════════════════════════════════╣
# ║ Restaurant : quantam              ║
# ║ Items      : 2 × Rs 350         ║
# ║ Subtotal   : Rs 700              ║
# ║ GST (18%)  : Rs 126              ║
# ║ Delivery   : Rs 40               ║
# ║ TOTAL      : Rs 866              ║
# ╚══════════════════════════════════╝

# %%
class BankAccount:
    def deposit():
        pass

# %%
def withdraw():
    pass

# %%
print(type("Manoj"))
# Out:
# <class 'str'>

# %%
# search methods

sentence = "rcb won the titile two times and also womens won 2 times"

# %%
sentence.find("titile")
# Out:
# 12

# %%
sentence.find("kohli")
# Out:
# -1

# %%
sentence.count("i")
# Out:
# 4

# %%
sentence.count("rcb")
# Out:
# 1

# %%
print("cricket" in sentence )
# Out:
# False

# %%
sentence.count("akaksha")
# Out:
# 0

# %%
# Replace

old_message = "hi bhai, how are you... bhai"

# %%
new_message = old_message.replace("bhai","Bro")

# %%
new_message
# Out:
# 'hi Bro, how are you... Bro'

# %%
score = "95,87,88,60,77:test,hello."

# %%
score_list = score.split(":")

# %%
score_list
# Out:
# ['95,87,88,60,77', 'test,hello.']

# %%
score_list[-2]
# Out:
# '77:test'

# %%
score[:2]
# Out:
# '95'

# %%
score_list[0]
# Out:
# '95'

# %%
# without f string
name = "smriti"
Jersy_no = 18

# %%
print("My fvt player is",name,"her jersy no is ",Jersy_no)
# Out:
# My fvt player is smriti her jersy no is  18

# %%
print(f"My fvt player is {name} and her jersy no is {Jersy_no}")
# Out:
# My fvt player is smriti and her jersy no is 18

# %%
f"text {expression} text"

# %%
a = 10
b = 20

print(f"toal is {a+b}")
# Out:
# toal is 30

# %%
name = "Virat Kohli"

# %%
print(f"{name:<15}")
# Out:
# Virat Kohli

# %%
test = f"{name:<15}"

# %%
len(test)
# Out:
# 15

# %%
len(name)
# Out:
# 11

# %%
name = "virat"

print(f"|{name:<15}|")
print(f"|{"sachin god":<15}|")
# Out:
# |virat          |
# |sachin god     |

# %%
print(f"|{name:>15}|")
print(f"|{"sachin god":>15}|")
# Out:
# |          virat|
# |     sachin god|

# %%
print(f"|{"sachin god of cricket and i like him":>15}|")
# Out:
# |sachin god of cricket and i like him|

# %%
print(f"|{name:^15}|")
print(f"|{"sachin god":^15}|")
# Out:
# |     virat     |
# |  sachin god   |

# %%
price = 123455.89
print(f"{price}")
# Out:
# 123455.89

# %%
print(f"{price:,.2f}")
# Out:
# 123,455.89

# %%
price = 1234567.89089
print(f"{price:,.2f}")
# Out:
# 1,234,567.89

# %%
print(f"{price:.2f}")
# Out:
# 1234567.89

# %%
print(f"{price:.1f}")
# Out:
# 1234567.9

# %%
print(f"{price:.3f}")
# Out:
# 1234567.891

# %%
score = 0.956

print(f"{score:.1%}")
# Out:
# 95.6%

# %%
print(f"{score:.2%}")
# Out:
# 95.60%

# %%
# Whastapp message formater
print("="*45)
print("   📲 WHATSAPP MESSAGE FORMATER")
print("="*45)

# take input from user
sender = input("your name: ").strip().title()
reciver = input("Friends name: ").strip().title()
message = input("your message: ").strip()
# you need to analyse that input
word_count = len(message.split())
char_count = len(message)
char_no_space = len(message.replace(" ",""))

# check if it is too formal 
is_formal = any(word in message.lower() for word in ["sir","mam","madam","dear"])
# check if the text contains emojis
has_emojis = any(char for char in message if ord(char) > 127)
# format the message
first_word = message.split()[0] if message else ""
preview = message[:30] + "..." if len(message) > 30 else message

# generate whatsapp style formatted output
print()
print("-"*45)
print(f" From    :{sender}")
print(f" To      :{reciver}")
print(f" Preview :{preview}")
print(f" words.  :{word_count}")
print(f" Chars.  :{char_count}")
print(f" Char    : {char_no_space} WOTHOUT SPACE")
print(f" FORMAL  :{ 'yes' if is_formal else 'No'}")
print(f" Emoji.  :{'yes' if has_emojis else 'No'}")
print("-"*45)
print()
print(f"\n ☁️ {sender} -> {reciver} ")
print(f" {message}")
print(f" ✓✓ 9:39 Pm")
print()
# suggest imporovements
# Out:
# ...
#    📲 WHATSAPP MESSAGE FORMATER
# ...
#
# ---------------------------------------------
#  From    :Manoj
#  To      :Akanksha
#  Preview :HELLO HOW ARE YOU
#  words.  :4
#  Chars.  :17
#  Char    : 14 WOTHOUT SPACE
#  FORMAL  :No
#  Emoji.  :No
# ---------------------------------------------
#
#
#  ☁️ Manoj -> Akanksha
#  HELLO HOW ARE YOU
#  ✓✓ 9:39 Pm

# %% [markdown]
# | Method | What it does | Example |
# |--------|-------------|---------|
# | `.upper()` | ALL CAPS | `"hello".upper()` → `"HELLO"` |
# | `.lower()` | all lowercase | `"HELLO".lower()` → `"hello"` |
# | `.title()` | Title Case | `"shah rukh".title()` → `"Shah Rukh"` |
# | `.strip()` | Remove edge spaces | `"  hi  ".strip()` → `"hi"` |
# | `.split(",")` | Break into list | `"a,b,c".split(",")` → `["a","b","c"]` |
# | `",".join(lst)` | Join list to string | `",".join(["a","b"])` → `"a,b"` |
# | `.replace(a,b)` | Replace text | `"Bhai".replace("B","Yaar")` |
# | `.find(x)` | Find position | `"hello".find("l")` → `2` |
# | `.count(x)` | Count occurrences | `"hello".count("l")` → `2` |
# | `.startswith(x)` | Check start | `"Rohit".startswith("R")` → `True` |
# | `.endswith(x)` | Check end | `"India".endswith("a")` → `True` |
# | `x in str` | Check if exists | `"God" in "God of Cricket"` → `True` |
# | `len(str)` | Length | `len("India")` → `5` |

# %% [markdown]
# ## Build: Bollywood Name Generator + SMS Validator

# %% [markdown]
# ```
# Part 1 — Bollywood Name Generator:
#   Input: Your real name (e.g., "Ramesh Kumar")
#   Output:
#     - Your Bollywood hero name (first name reversed, last name CAPS)
#     - Your villain name (all uppercase with "The" prefix)
#     - Your comedian name (title case + "ji" added)
#
#   Example: "ramesh kumar" →
#     Hero   : "Hsemer KUMAR"
#     Villain: "THE RAMESH KUMAR"
#     Comedian: "Ramesh Kumar Ji"
#
# Part 2 — SMS Validator:
#   Input: User types an SMS message
#   Output:
#     - Character count (SMS limit: 160)
#     - How many SMSes it will take (1 SMS = 160 chars)
#     - Cost (Rs 0.50 per SMS)
#     - Show what gets cut if it exceeds 160 chars
#     - Whether it contains any bad words (check 3-4 words)
#
# ```
